# %% [markdown]
# - Exploratory Data Analysis (EDA)

# %%
#Importing all the necessary libraries i will use  to do the data exploratory and analysis
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Loading the dataset
df = pd.read_csv(r"C:\Users\User\Downloads\population-and-demography.csv\population-and-demography.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18288 entries, 0 to 18287
# Data columns (total 24 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                18288 non-null  object
#  1   Year                                        18288 non-null  int64
#  2   Population                                  18288 non-null  int64
#  3   Population of children under the age of 1   18288 non-null  float64
#  4   Population of children under the age of 5   18288 non-null  int64
#  5   Population of children under the age of 15  18288 non-null  int64
#  6   Population under the age of 25              18288 non-null  int64
#  7   Population aged 15 to 64 years              18288 non-null  int64
#  8   Population older than 15 years              18288 non-null  int64
#  9   Population older than 18 years              18288 non-null  int64
# ...

# %%
df.head()
# Out:
#   Country name  Year  Population  Population of children under the age of 1  \
# 0  Afghanistan  1950     7480464                                   301735.0
# 1  Afghanistan  1951     7571542                                   299368.0
# 2  Afghanistan  1952     7667534                                   305393.0
# 3  Afghanistan  1953     7764549                                   311574.0
# 4  Afghanistan  1954     7864289                                   317584.0
#
#    Population of children under the age of 5  \
# 0                                    1248282
# 1                                    1246857
# 2                                    1248220
# 3                                    1254725
# 4                                    1267817
#
#    Population of children under the age of 15  Population under the age of 25  \
# 0                                     3068855                         4494349
# ...

# %%
# Print all unique country names
country_names = df['Country name'].unique()
print(country_names)
# Out:
# ['Afghanistan' 'Africa (UN)' 'Albania' 'Algeria' 'American Samoa'
#  'Andorra' 'Angola' 'Anguilla' 'Antigua and Barbuda' 'Argentina' 'Armenia'
#  'Aruba' 'Asia (UN)' 'Australia' 'Austria' 'Azerbaijan' 'Bahamas'
#  'Bahrain' 'Bangladesh' 'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin'
#  'Bermuda' 'Bhutan' 'Bolivia' 'Bonaire Sint Eustatius and Saba'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cambodia' 'Cameroon'
#  'Canada' 'Cape Verde' 'Cayman Islands' 'Central African Republic' 'Chad'
#  'Chile' 'China' 'Colombia' 'Comoros' 'Congo' 'Cook Islands' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia'
#  'Democratic Republic of Congo' 'Denmark' 'Djibouti' 'Dominica'
#  'Dominican Republic' 'East Timor' 'Ecuador' 'Egypt' 'El Salvador'
#  'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini' 'Ethiopia'
#  'Europe (UN)' 'Falkland Islands' 'Faroe Islands' 'Fiji' 'Finland'
# ...

# %%
# Print the count of duplicated rows in the DataFrame
print(df.duplicated().sum())
# Out:
# 0

# %%
# Generate random data representing daily temperatures over one year
data = np.random.normal(loc=20.0, scale=5.0, size=365)

# Create a histogram of the data with specified bins, color, and transparency
plt.hist(data, bins=20, color='blue', alpha=0.7)

# Set the title of the plot
plt.title('Histogram of Population per country ')

# Set the label for the x-axis
plt.xlabel('Country name')

# Set the label for the y-axis
plt.ylabel('Population')

# Display grid lines on the plot
plt.grid(True)

# Show the plot
plt.show()

# %%
Country = ['Zimbabwe', 'Afghanistan', 'Algeria', 'Italy']
Population= [792207, 296032, 736350, 356244]
# Creating pie chart
plt.figure(figsize=(7, 7))
plt.pie(Population, labels=Country, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart Pupulation share')  
plt.show()

# %%
plt.scatter(Population, Country)
plt.title('Scatter Plot of Population vs. Country')
plt.xlabel('Population')
plt.ylabel('Country')
plt.show()

# %%
# Data
countries = ['Indonesia', 'Brazil', 'United States', ' China', 'Pakistan', 'India', 'Nigeria', 'Bangladesh', 'Russia', 'Mexico']
population = [1444216107, 1393409038, 332915073, 276361783, 225199937, 214280581, 211400708, 166303498, 145912025, 130262216]

# Sort data
population, countries = zip(*sorted(zip(population, countries), reverse=True))

# Funnel plot
plt.figure(figsize=(10, 6))
plt.fill_betweenx(range(len(countries)), 0, population, color="skyblue", alpha=0.4)
plt.plot(population, range(len(countries)), marker='o', color="skyblue", alpha=0.6)

# Labels
plt.yticks(range(len(countries)), countries)
plt.title('Funnel Plot of Population by Country')
plt.xlabel('Population')
plt.ylabel('Country')
plt.grid(True, axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

# Show plot
plt.show()

# %%
# Sample data
Population = [100, 200, 300, 400, 500]

# Creating a boxplot
plt.figure(figsize=(6, 5))
plt.boxplot(Population)
plt.title('Boxplot of Population')
plt.ylabel('Population')

# Show the plot
plt.show()

# %%
Population= [792207, 296032, 736350, 356244]

# Convert the list of years to numpy array
Population_array = np.array(Population)

# Calculate summary statistics
mean = np.mean(Population_array)
median = np.median(Population_array)
std_dev = np.std(Population_array)

print("Mean:", mean)
print("Median:", median)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 545208.25
# Median: 546297.0
# Standard Deviation: 220986.33579745944
